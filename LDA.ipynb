# %%
import pandas as pd

# %%
import nltk
from nltk.corpus import stopwords
import re

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\admin
# [nltk_data]     nvme\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_excel('Book1.xlsx')
df
# Out:
#                                      Constructs  \
# 0                                   Air Quality
# 1                           Economic Indicators
# 2                                  Urbanization
# 3                    Pollution Control Measures
# 4                                    Megaevents
# ..                                          ...
# 749  Ecologically Sustainable Development (ESD)
# 750                           Public Perception
# 751                      Stakeholder Engagement
# 752                      Remediation Strategies
# 753                     Environmental Standards
#
#                                              Variables
# 0                 Air Quality Index , PM2.5, PM10, NO2
# 1    Gross Domestic Product, Fiscal Revenue, Fiscal...
# 2                                      Population Size
# 3    Implementation of green power sources, constru...
# 4                  Size, Scale, Complexity, Uniqueness
# ..                                                 ...
# 749  Resource use, intergenerational equity, pollut...
# 750  Media coverage, public awareness, community co...
# 751  Community consultation, environmental advocacy...
# 752  Contaminant removal, site containment, environ...
# 753  Best practices, regulatory compliance, interna...
#
# [754 rows x 2 columns]

# %%
df['combined_text']=df['Constructs'] + " " + df['Variables']

# %%
def preprocess_text(text):
    stop_words = set(stopwords.words('english'))
    text = re.sub(r'\W+', ' ', text)  # Remove special characters
    text = text.lower()  # Convert to lowercase
    words = text.split()
    words = [word for word in words if word not in stop_words]  # Remove stopwords
    return " ".join(words)


df['cleaned_text'] = df['combined_text'].apply(preprocess_text)

# %%
vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
dtm = vectorizer.fit_transform(df['cleaned_text'])

# %%
lda = LatentDirichletAllocation(n_components=5, random_state=2)
lda.fit(dtm)
# Out:
# LatentDirichletAllocation(n_components=5, random_state=2)

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print(f"Topic {topic_idx}:")
        print(" ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))

no_top_words = 5
tf_feature_names = vectorizer.get_feature_names_out()
display_topics(lda, tf_feature_names, no_top_words)
# Out:
# Topic 0:
# economic impact tourism growth development
# Topic 1:
# media cultural national public events
# Topic 2:
# social community impact environmental engagement
# Topic 3:
# urban development infrastructure public sports
# Topic 4:
# political policy government management event
